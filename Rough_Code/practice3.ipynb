# %%
import numpy as np

# %%
print("Soumya",end='')
print("********")
# Out:
# Soumya********

# %%
a=complex(3,2)
print(a)
# Out:
# (3+2j)

# %%
#dictionary{}

dic={
    'three': 3,
    'four':4
}
dic['one']=1
dic['two']=2

for i in dic.keys():
    print(f"{i} --> {dic[i]}")
# Out:
# three --> 3
# four --> 4
# one --> 1
# two --> 2

# %%
print(10//3)
print(10/3)
# Out:
# 3
# 3.3333333333333335

# %%
x=5
a=bin(x)
a
# Out:
# '0b101'

# %%
#is compares memory location of two elements
a=[1,2,3]
b=[1,2,3]
print(a is b)
b=a
print(a is b)
b=a[:]
print(a is b)
# Out:
# False
# True
# False

# %%
a=list(range(5))
a
# Out:
# [0, 1, 2, 3, 4]

# %%
l=[1,2,3,5,67,23,54,63,2,123,321,43,32]
for i in l:
    print(i,end=" ")

print()
for i in range(len(l)):
    print(l[i],end=" ")
print()
# Out:
# 1 2 3 5 67 23 54 63 2 123 321 43 32
# 1 2 3 5 67 23 54 63 2 123 321 43 32

# %%
def printinfo(age, name):
    print(f"name: {name}, age: {age}")

printinfo(name="soumya",age=22)
# Out:
# name: soumya, age: 22

# %%
def printinfo(arg, *var):
    print(arg)
    for i in var:
        print(i)


printinfo(10)
printinfo(21,2,4,5,6,5)
printinfo()
# Out:
# 10
# 21
# 2
# 4
# 5
# 6
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 9
#       7 printinfo(10)
#       8 printinfo(21,2,4,5,6,5)
# ----> 9 printinfo()
#
# TypeError: printinfo() missing 1 required positional argument: 'arg'
