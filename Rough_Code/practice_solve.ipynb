# %%
# Out:
# spike 3 3
# noise 1 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       2 ls=[()]
#       4 for i in range(0,n,1):
# ----> 5     a,b,c=map(str,input().split(" "))
#       6     print(a,b,c)
#       7     # label=input()
#       8     # amp=int(input())
#       9     # dur=int(input())
#      10     # ls.append((label,a))
#
# ValueError: too many values to unpack (expected 3)
