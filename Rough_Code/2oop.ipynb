# %%
class Student:
    static_var=10
    def __init__(self,id,name):
        self.id=id
        self.name=name

    def __str__(self):
        return f" Student {self.name} id {self.id}"
    
    def __repr__(self):  #this is for jupeter notebook
        return f" Student {self.name} id {self.id}"
    
std = Student(142,"Soumya deep sarker")
std
# Out:
#  Student Soumya deep sarker id 142

# %%
std.static_var
# Out:
# 10
